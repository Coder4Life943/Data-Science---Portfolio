# %%
# !Jupyter nbconvert --to html Trevor_Mukuve_2414222_Regression1.ipynb
# Out:
# [NbConvertApp] Converting notebook Trevor_Mukuve_2414222_Regression1.ipynb to html
# [NbConvertApp] Writing 602407 bytes to Trevor_Mukuve_2414222_Regression1.html

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
dataset = pd.read_csv('car_insurance_premium_dataset.csv')

# %%
X = dataset.iloc[ : , :6]
Y = dataset.iloc[ : ,6]

# %%
#Splittin
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=1000)

# %%
regressor = RandomForestRegressor(n_estimators=5, max_depth=11)
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=11, n_estimators=5)

# %%
predictions = regressor.predict(X_test)

# %%
print(predictions)
print(Y_test)
# Out:
# [492.72       489.1825     503.54333333 498.60333333 491.57333333
#  497.585      492.08333333 500.61333333 501.57       498.925
#  498.81333333 494.14       487.21333333 495.94       499.44
#  492.69916667 489.11       494.42166667 497.65       490.11
#  491.925      497.14937984 490.375      503.7        494.815
#  498.19666667 503.41       492.8        483.828      492.
#  493.93       494.75857143 498.18333333 497.03       499.68833333
#  497.88166667 499.44       499.22833333 495.4452381  496.56
#  493.64604651 492.46333333 483.59       499.22       504.10333333
#  489.72833333 495.5425     489.52       493.35       491.45866667
#  492.73125    481.96571429 495.99666667 498.9575     494.74
#  487.821      495.91866667 490.2        502.88       499.52
#  489.74       501.62       491.09333333 488.6        493.31937984
#  495.78       484.3025     501.93       501.19       491.89937984
#  498.46937984 497.86333333 487.02       491.19       499.79666667
# ...

# %%
r_square = metrics.r2_score(Y_test, predictions)
print(r_square)
# Out:
# 0.9747781884542196
