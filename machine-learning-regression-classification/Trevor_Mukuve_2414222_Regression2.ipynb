# %%
# !Jupyter nbconvert --to html Trevor_Mukuve_2414222_Regression1.ipynb
# Out:
# [NbConvertApp] Converting notebook Trevor_Mukuve_2414222_Regression1.ipynb to html
# [NbConvertApp] Writing 592467 bytes to Trevor_Mukuve_2414222_Regression1.html

# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
dataset = pd.read_csv('car_insurance_premium_dataset.csv')

# %%
X = dataset.iloc[ : , :6]
Y = dataset.iloc[ : ,6]
Y
# Out:
# 0      488.35
# 1      486.15
# 2      497.55
# 3      498.35
# 4      495.55
#         ...
# 995    500.00
# 996    494.55
# 997    506.05
# 998    491.45
# 999    492.80
# Name: Insurance Premium ($), Length: 1000, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=1000)

# %%
regressor = SVR(kernel = 'linear', C=4)
regressor.fit(X_train, Y_train)
# Out:
# SVR(C=4, kernel='linear')

# %%
predictions = regressor.predict(X_test)

# %%
print(predictions)
print(Y_test)
# Out:
# [493.92011007 488.02019248 504.79975264 498.79992743 491.86988977
#  499.79987202 493.10985828 500.33974741 499.97988137 498.6097587
#  500.04972679 493.04998225 487.75015204 495.94017476 498.34002843
#  492.9100737  487.60008734 494.64008825 496.23999243 491.5499893
#  491.57001994 497.62987912 489.73003139 504.9497699  495.57988611
#  497.43996297 502.82976298 493.4398756  483.13012869 490.56008078
#  493.65999965 495.19977364 498.74982621 497.44977161 499.43976101
#  498.34997003 500.21985716 499.48973286 496.39979544 495.78992816
#  494.05985224 491.49000621 484.47009318 499.71991112 504.73975932
#  490.56992874 496.74995912 489.39994856 494.28984798 490.28004602
#  492.82005805 480.60020244 495.33008706 499.1797433  493.73993721
#  487.79010753 494.38014306 491.75000621 502.82976723 500.06989989
#  487.9900239  501.51975591 489.90999052 487.47003733 492.55996416
#  497.52984512 484.45996865 503.49973681 500.23985793 491.95998377
#  498.67978912 499.04999605 487.37998088 491.30006085 498.28994488
#  499.24982015 496.85010758 501.28979594 494.84995106 507.89961809
#  503.4796833  491.27028026 504.04977706 489.56008955 486.05004805
#  489.44006454 498.04996438 494.75982943 489.93002978 503.08981722
#  501.67984277 485.95004304 484.200128   496.34983703 493.91007642
#  495.94981016 496.12997175 497.54990938 493.74980386 490.55006355
#  491.9600356  499.63972805 493.62997491 499.54973683 491.35999579
#  496.95993426 486.65002895 496.7599601  499.53978583 501.5297721
#  498.81977662 500.509693   490.31993595 499.90985095 490.25997205
#  501.42969521 503.38973601 496.29991814 498.90989578 490.49006622
#  498.99991838 493.28020307 498.9497752  489.81990914 496.55003104
#  499.59977951 502.22969046 504.52963225 493.65017171 498.33985871
#  493.72982852 499.52991397 491.26992374 495.40000383 493.49997954
#  487.74006558 501.22987847 488.35016955 494.74989969 496.02994679
#  492.44986966 494.60978392 502.09982829 485.52015611 498.28998694
#  494.0299947  493.93984255 483.3801657  501.24998184 499.32981859
#  492.50004292 494.57995257 496.94993083 502.31974103 483.12025566
#  494.17981408 494.349941   498.18988018 490.5698815  488.21006646
#  485.66008421 496.62989996 496.08003047 484.96018286 489.76993122
#  498.12996993 504.44978939 487.9701055  494.95005527 489.38996586
#  500.96982423 496.6298432  499.95982808 491.64997106 500.21983602
#  493.87981945 496.46993318 492.54005938 503.58977141 490.54000879
#  496.39983968 498.65978226 497.06991759 498.20981796 487.04993186
#  490.7999511  494.61980436 495.89974657 493.81002078 505.74965447
#  489.3501586  500.32992654 499.14974152 492.40998105 491.64008769
#  501.75971079 489.39007317 481.80020989 494.34996499 488.18009768]
# 967    493.90
# 713    488.00
# 222    504.90
# 321    498.90
# 898    491.85
#         ...
# 136    501.70
# 186    489.45
# 973    481.70
# 394    494.25
# 586    488.20
# Name: Insurance Premium ($), Length: 200, dtype: float64

# %%
r_square = metrics.r2_score(Y_test, predictions)
print(r_square)
# Out:
# 0.9998424602016159
